# %%
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

import numpy as np
import pandas as pd

from scipy.stats import binned_statistic
from scipy.optimize import curve_fit

import gm2
import trfp
import plotting_functions as plt2
# import analysis_helper as helper
# import helper_function_candidates as helper_old
# import df_analysis_funcs as df_func
import helper_functions as helper

import field_map_config_run1 as map_config

from IPython.display import clear_output

# blinds = np.loadtxt('blinds.txt')
pair_dict = map_config.pair_dict
# Out:
# Welcome to JupyROOT 6.22/02

# %%
x = np.array(trfp.geometry.TR_X)
y = np.array(trfp.geometry.TR_Y)
z = np.array(trfp.geometry.PLUNGING_PROBE_CALIBRATIONS)

# %%
fig, ax = plt.subplots(1)

plot = ax.tricontourf(x,y,z, levels=100)
ax.set_xlabel('cm')
ax.set_xlim(4,-4)
ax.set_ylabel('cm')
ax.set_ylim(-4,4)
ax.set_title('Trolley Calibration')
ax.set_aspect('equal')
plot_cb = plt.colorbar(plot)
plot_cb.set_label('Calibration (Hz)')
fig.set_size_inches(10,8)
fig.tight_layout
# Out:
# <bound method Figure.tight_layout of <Figure size 720x576 with 2 Axes>>

# %%
z
# Out:
# array([ 87.521,  81.002,  91.643,  83.039,  89.962, 103.194, 113.698,
#         73.605,  80.592,  20.797, 174.332, 107.95 , 120.301,  74.745,
#         72.838,  18.166, 169.407])
