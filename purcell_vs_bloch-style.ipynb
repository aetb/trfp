# %%
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

import numpy as np
import pandas as pd

from scipy.optimize import curve_fit

import gm2
import trfp
import plotting_functions as plt2
import analysis_helper as helper
import helper_function_candidates as helper_old
# Out:
# Welcome to JupyROOT 6.12/04

# %%
# import the normal and bloch-style vtms

df_1 = pd.read_hdf('hdf5/9day_moments_blinded.h5', 'vtm_1')
df_2 = pd.read_hdf('hdf5/9day_moments_blinded_bloch-style.h5', 'vtm_1')

# %%
plt.plot(df_1['st1,m1'], '.')
plt.plot(df_2['st1,m1'], '.')

# %%
print np.mean(df_1['st1,m1'])
print np.mean(df_2['st1,m1'])
# Out:
# 51007.81501282489
# 51052.39934439131

# %%
fp_run = gm2.FixedProbe(range(4175,4179), prefix='data1/newg2/DataProduction/Offline/ArtTFSDir/v9_21_05_dev/FieldPlainRootOutput_')

# %%
fp_time, fp_freq, fp_qual = fp_run.getBasics()
# Out:
# Reading event 13120/13122 99.98%
# loop done: 100%

# %%
fp_run.qtag.shape
# Out:
# (13122, 378)

# %%
fp_qual.shape
# Out:
# (13122, 378)

# %%
print 2**16
print np.sum(fp_qual[:,3]-2**16)
# Out:
# 65536
# -65536.0

# %%
plt.plot(fp_freq[1:,23])

# %%
test_df = pd.read_hdf('hdf5/9day.h5', 'fp_df_1')

# %%
plt.plot(test_df['fp5'],'.')
