# %%
import gm2
import trfp
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import helper_functions as helper

# %%
df = helper.root_to_pandas(run_range=range(3959,3995), prefix='FieldPlainRootOutput_', tr_run=False, sanitize=False)
# Out:
# Reading event 154050/154052 100.00%
# loop done: 100%

# %%
df.head()
# Out:
#                        fp0           fp1           fp2           fp3  \
# 1.524384e+09  44817.157394  50136.143085  54504.844966  49222.403486
# 1.524384e+09  44816.853938  50136.383431  54504.871734  49176.101956
# 1.524384e+09  44815.288546  50136.572051  54504.604429  49098.899450
# 1.524384e+09  44813.922889  50136.223303  54505.014676  49179.527267
# 1.524384e+09  44813.705399  50135.951494  54505.467368  49251.639067
#
#                        fp4           fp5           fp6           fp7  \
# 1.524384e+09  61605.945836  67063.119021  34869.157832  50681.428771
# 1.524384e+09  61574.863820  67117.067125  34868.284345  50682.467838
# 1.524384e+09  61525.580222  67151.419394  34870.333399  50681.183385
# 1.524384e+09  61548.332509  67109.776990  34866.470079  50680.254950
# 1.524384e+09  61580.041449  67058.274815  34862.033976  50679.834631
#
#                        fp8           fp9  ...         fp368         fp369  \
# ...
