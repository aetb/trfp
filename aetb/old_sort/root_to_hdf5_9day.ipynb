# %%
import trfp
from IPython.display import clear_output
# Out:
# Welcome to JupyROOT 6.12/04

# %%
# %%time
# First trolley run of 9 day set (First of short part)
file_name = "9day_trolley_runs_1.h5"
for run in range(4136,4141):
    
    clear_output()
    print "Saving run " + str(run) + '.'

    trolley_run = trfp.Run(run)
    trolley_run.save_h5(file_name)

# %%
# %%time
# Second trolley run of 9 day set (Second of short part)
file_name = "9day_trolley_runs_2.h5"
for run in range(4179,4182): # note this cuts out runs 4182, 4183 during slow dump
    
    clear_output()
    print "Saving run " + str(run) + '.'

    trolley_run = trfp.Run(run)
    trolley_run.save_h5(file_name)

# %%
# %%time
# Third trolley run of 9 day set (First of long part)
file_name = "9day_trolley_runs_3.h5"
for run in range(4188,4193):
    
    clear_output()
    print "Saving run " + str(run) + '.'

    trolley_run = trfp.Run(run)
    trolley_run.save_h5(file_name)

# %%
# %%time
# Fourth trolley run of 9 day set (Second of long part)
file_name = "9day_trolley_runs_4.h5"
for run in range(4223,4227)+range(4228,4229):  # note there is no 4227 for now, should be soon

    
    clear_output()
    print "Saving run " + str(run) + '.'

    trolley_run = trfp.Run(run)
    trolley_run.save_h5(file_name)

# %%
# %%time
# Fifth trolley run of 9 day set (Third of long part)
file_name = "9day_trolley_runs_5.h5"
for run in range(4263,4268):
    
    clear_output()
    print "Saving run " + str(run) + '.'

    trolley_run = trfp.Run(run)
    trolley_run.save_h5(file_name)

# %%
# %%time
# Sixth trolley run of 9 day set (Fourth of long part)
file_name = "9day_trolley_runs_6.h5"
for run in range(4489,4494):
    
    clear_output()
    print "Saving run " + str(run) + '.'

    trolley_run = trfp.Run(run)
    trolley_run.save_h5(file_name)

# %%
# %%time

# The following runs were missed:[4146, 4168, 4178]
# CPU times: user 8min 53s, sys: 2min 13s, total: 11min 6s
# Wall time: 9min 38s

# First fixed probe run of 9 day set (short part)
missed_runs = []
file_name = "9day_fixed_probe_runs_1.h5"
for run in range(4141,4179):
    
#     clear_output()
    print "Saving run " + str(run) + '.'
    try:
        fixed_probe_run = trfp.Run(run)
        fixed_probe_run.save_h5(file_name)
    except IndexError:
        print '##################'
        print '##################'
        print 'Run ' + str(run) + ' is empty!'
        print '##################'
        print '##################'
        missed_runs = missed_runs + [run]
    except:
        print '##################'
        print '##################'
        print 'Something went wrong with run ' + str(run) + '.'
        print '##################'
        print '##################'
        missed_runs = missed_runs + [run]

    print '\n'
print 'The following runs were missed:' + str(missed_runs)

# Error in <TFile::TFile>: file /home/newg2/DataProduction/Offline/ArtTFSDir/v9_20_00//FieldPlainRootOutput_04146_tier1.root does not exist
# Error in <TFile::TFile>: file /home/newg2/DataProduction/Offline/ArtTFSDir/v9_20_00//FieldPlainRootOutput_04146_tier1.root does not exist
# Error in <TFile::TFile>: file /home/newg2/DataProduction/Offline/ArtTFSDir/v9_20_00//FieldPlainRootOutput_04146_tier1.root does not exist
# Error in <TChain::LoadTree>: Cannot find tree with name TreeGenTrolley/trolley in file /home/newg2/DataProduction/Offline/ArtTFSDir/v9_20_00//FieldPlainRootOutput_04168_tier1.root
# Error in <TChain::LoadTree>: Cannot find tree with name TreeGenFixedProbe/fixedProbe in file /home/newg2/DataProduction/Offline/ArtTFSDir/v9_20_00//FieldPlainRootOutput_04168_tier1.root
# Error in <TChain::LoadTree>: Cannot find tree with name TreeGenFixedProbe/fixedProbe in file /home/newg2/DataProduction/Offline/ArtTFSDir/v9_20_00//FieldPlainRootOutput_04168_tier1.root
# Error in <TFile::TFile>: file /home/newg2/DataProduction/Offline/ArtTFSDir/v9_20_00//FieldPlainRootOutput_04178_tier1.root does not exist
# Error in <TFile::TFile>: file /home/newg2/DataProduction/Offline/ArtTFSDir/v9_20_00//FieldPlainRootOutput_04178_tier1.root does not exist
# Error in <TFile::TFile>: file /home/newg2/DataProduction/Offline/ArtTFSDir/v9_20_00//FieldPlainRootOutput_04178_tier1.root does not exist
# Out:
# Saving run 4141.
# Fixed probe run.
# Reading event 4360/4367 99.84%
# loop done: 100%
# Interpolating fixed probe frequencies.
# Finished calculating all moments for 7285 events.
# Saving run 4141.
#
#
# Saving run 4142.
# Fixed probe run.
# Reading event 4360/4370 99.77%
# loop done: 100%
# Interpolating fixed probe frequencies.
# Finished calculating all moments for 7290 events.
# Saving run 4142.
#
#
# Saving run 4143.
# Fixed probe run.
# Reading event 4360/4370 99.77%
# loop done: 100%
# Interpolating fixed probe frequencies.
# Finished calculating all moments for 7289 events.
# Saving run 4143.
#
#
# Saving run 4144.
# Fixed probe run.
# Reading event 4360/4370 99.77%
# loop done: 100%
# Interpolating fixed probe frequencies.
# Finished calculating all moments for 7289 events.
# Saving run 4144.
#
#
# Saving run 4145.
# Fixed probe run.
# Reading event 4360/4370 99.77%
# loop done: 100%
# Interpolating fixed probe frequencies.
# ...

# %%
# # look for missing fixed probe runs

# # have fixed probe runs [4164--4177]
# # have fixed probe runs [4183--4222]
# # have fixed probe runs [4229--4262]
# # have fixed probe runs [4283--4366]

# import os

# path_1 = '/home/newg2/DataProduction/Offline/ArtTFSDir/v9_20_00/FieldPlainRootOutput_0'
# path_2 = '_tier1.root'

# for run in range(4283,4367):
#     file_name = path_1 + str(run) + path_2
#     exists = os.path.isfile(file_name)
#     if exists == False:
#         print 'Missing run ' + str(run)

# %%
# %%time

# The following runs were missed:[]
# CPU times: user 7min 18s, sys: 1min 42s, total: 9min 1s
# Wall time: 7min 57s

# Second fixed probe run of 9 day set (long part 1)
missed_runs = []
file_name = "9day_fixed_probe_runs_2.h5"
for run in range(4193,4223):
    
#     clear_output()
    print "Saving run " + str(run) + '.'
    try:
        fixed_probe_run = trfp.Run(run)
        fixed_probe_run.save_h5(file_name)
    except IndexError:
        print '##################'
        print '##################'
        print 'Run ' + str(run) + ' is empty!'
        print '##################'
        print '##################'
        missed_runs = missed_runs + [run]
    except:
        print '##################'
        print '##################'
        print 'Something went wrong with run ' + str(run) + '.'
        print '##################'
        print '##################'
        missed_runs = missed_runs + [run]

    print '\n'
print 'The following runs were missed:' + str(missed_runs)
# Out:
# Saving run 4193.
# Fixed probe run.
# Reading event 4360/4367 99.84%
# loop done: 100%
# Interpolating fixed probe frequencies.
# Finished calculating all moments for 7267 events.
# Saving run 4193.
#
#
# Saving run 4194.
# Fixed probe run.
# Reading event 4360/4370 99.77%
# loop done: 100%
# Interpolating fixed probe frequencies.
# Finished calculating all moments for 7271 events.
# Saving run 4194.
#
#
# Saving run 4195.
# Fixed probe run.
# Reading event 4360/4370 99.77%
# loop done: 100%
# Interpolating fixed probe frequencies.
# Finished calculating all moments for 7271 events.
# Saving run 4195.
#
#
# Saving run 4196.
# Fixed probe run.
# Reading event 4360/4370 99.77%
# loop done: 100%
# Interpolating fixed probe frequencies.
# Finished calculating all moments for 7272 events.
# Saving run 4196.
#
#
# Saving run 4197.
# Fixed probe run.
# Reading event 4360/4370 99.77%
# loop done: 100%
# Interpolating fixed probe frequencies.
# ...

# %%
# %%time

# The following runs were missed:[]
# CPU times: user 8min 34s, sys: 1min 59s, total: 10min 33s
# Wall time: 8min 13s

# Third fixed probe run of 9 day set (long part 2)
missed_runs = []
file_name = "9day_fixed_probe_runs_3.h5"
for run in range(4229,4263):
    
#     clear_output()
    print "Saving run " + str(run) + '.'
    try:
        fixed_probe_run = trfp.Run(run)
        fixed_probe_run.save_h5(file_name)
    except IndexError:
        print '##################'
        print '##################'
        print 'Run ' + str(run) + ' is empty!'
        print '##################'
        print '##################'
        missed_runs = missed_runs + [run]
    except:
        print '##################'
        print '##################'
        print 'Something went wrong with run ' + str(run) + '.'
        print '##################'
        print '##################'
        missed_runs = missed_runs + [run]

    print '\n'
print 'The following runs were missed:' + str(missed_runs)
# Out:
# Saving run 4229.
# Fixed probe run.
# Reading event 4370/4374 99.91%
# loop done: 100%
# Interpolating fixed probe frequencies.
# Finished calculating all moments for 7279 events.
# Saving run 4229.
#
#
# Saving run 4230.
# Fixed probe run.
# Reading event 4370/4374 99.91%
# loop done: 100%
# Interpolating fixed probe frequencies.
# Finished calculating all moments for 7279 events.
# Saving run 4230.
#
#
# Saving run 4231.
# Fixed probe run.
# Reading event 4370/4376 99.86%
# loop done: 100%
# Interpolating fixed probe frequencies.
# Finished calculating all moments for 7283 events.
# Saving run 4231.
#
#
# Saving run 4232.
# Fixed probe run.
# Reading event 4370/4375 99.89%
# loop done: 100%
# Interpolating fixed probe frequencies.
# Finished calculating all moments for 7282 events.
# Saving run 4232.
#
#
# Saving run 4233.
# Fixed probe run.
# Reading event 4370/4375 99.89%
# loop done: 100%
# Interpolating fixed probe frequencies.
# ...

# %%
# %%time

# The following runs were missed:[4269, 4270, 4272, 4273, 4276, 4277, 4367]
# CPU times: user 6min 56s, sys: 8.84 s, total: 7min 4s
# Wall time: 10min 47s

# Fourth fixed probe run of 9 day set (long part 3)
missed_runs = []
file_name = "9day_fixed_probe_runs_4.h5"
for run in range(4268,4489):
    
#     clear_output()
    print "Saving run " + str(run) + '.'
    try:
        fixed_probe_run = trfp.Run(run)
        fixed_probe_run.save_h5(file_name)
    except IndexError:
        print '##################'
        print '##################'
        print 'Run ' + str(run) + ' is empty!'
        print '##################'
        print '##################'
        missed_runs = missed_runs + [run]
    except:
        print '##################'
        print '##################'
        print 'Something went wrong with run ' + str(run) + '.'
        print '##################'
        print '##################'
        missed_runs = missed_runs + [run]

    print '\n'
print 'The following runs were missed:' + str(missed_runs)

# Error in <TFile::TFile>: file /home/newg2/DataProduction/Offline/ArtTFSDir/v9_20_00//FieldPlainRootOutput_04269_tier1.root does not exist
# Error in <TFile::TFile>: file /home/newg2/DataProduction/Offline/ArtTFSDir/v9_20_00//FieldPlainRootOutput_04269_tier1.root does not exist
# Error in <TFile::TFile>: file /home/newg2/DataProduction/Offline/ArtTFSDir/v9_20_00//FieldPlainRootOutput_04269_tier1.root does not exist
# Error in <TFile::TFile>: file /home/newg2/DataProduction/Offline/ArtTFSDir/v9_20_00//FieldPlainRootOutput_04270_tier1.root does not exist
# Error in <TFile::TFile>: file /home/newg2/DataProduction/Offline/ArtTFSDir/v9_20_00//FieldPlainRootOutput_04270_tier1.root does not exist
# Error in <TFile::TFile>: file /home/newg2/DataProduction/Offline/ArtTFSDir/v9_20_00//FieldPlainRootOutput_04270_tier1.root does not exist
# Error in <TFile::TFile>: file /home/newg2/DataProduction/Offline/ArtTFSDir/v9_20_00//FieldPlainRootOutput_04272_tier1.root does not exist
# Error in <TFile::TFile>: file /home/newg2/DataProduction/Offline/ArtTFSDir/v9_20_00//FieldPlainRootOutput_04272_tier1.root does not exist
# Error in <TFile::TFile>: file /home/newg2/DataProduction/Offline/ArtTFSDir/v9_20_00//FieldPlainRootOutput_04272_tier1.root does not exist
# Error in <TFile::TFile>: file /home/newg2/DataProduction/Offline/ArtTFSDir/v9_20_00//FieldPlainRootOutput_04273_tier1.root does not exist
# Error in <TFile::TFile>: file /home/newg2/DataProduction/Offline/ArtTFSDir/v9_20_00//FieldPlainRootOutput_04273_tier1.root does not exist
# Error in <TFile::TFile>: file /home/newg2/DataProduction/Offline/ArtTFSDir/v9_20_00//FieldPlainRootOutput_04273_tier1.root does not exist
# Error in <TFile::TFile>: file /home/newg2/DataProduction/Offline/ArtTFSDir/v9_20_00//FieldPlainRootOutput_04276_tier1.root does not exist
# Error in <TFile::TFile>: file /home/newg2/DataProduction/Offline/ArtTFSDir/v9_20_00//FieldPlainRootOutput_04276_tier1.root does not exist
# Error in <TFile::TFile>: file /home/newg2/DataProduction/Offline/ArtTFSDir/v9_20_00//FieldPlainRootOutput_04276_tier1.root does not exist
# Error in <TFile::TFile>: file /home/newg2/DataProduction/Offline/ArtTFSDir/v9_20_00//FieldPlainRootOutput_04277_tier1.root does not exist
# Error in <TFile::TFile>: file /home/newg2/DataProduction/Offline/ArtTFSDir/v9_20_00//FieldPlainRootOutput_04277_tier1.root does not exist
# Error in <TFile::TFile>: file /home/newg2/DataProduction/Offline/ArtTFSDir/v9_20_00//FieldPlainRootOutput_04277_tier1.root does not exist
# Error in <TFile::TFile>: file /home/newg2/DataProduction/Offline/ArtTFSDir/v9_20_00//FieldPlainRootOutput_04367_tier1.root does not exist
# Error in <TFile::TFile>: file /home/newg2/DataProduction/Offline/ArtTFSDir/v9_20_00//FieldPlainRootOutput_04367_tier1.root does not exist
# Error in <TFile::TFile>: file /home/newg2/DataProduction/Offline/ArtTFSDir/v9_20_00//FieldPlainRootOutput_04367_tier1.root does not exist
# Out:
# Saving run 4268.
# Trolley run.
# Reading event 1100/1106 99.46%
# loop done: 100%
# Reading event 330/332 99.40%
# loop done: 100%
# Interpolating trolley position.
# Interpolating trolley frequencies.
# Interpolating fixed probe frequencies.
# Finished calculating all moments for 545 events.
# Saving run 4268.
#
#
# Saving run 4269.
# Fixed probe run.
# Cannot load ids, no data present
#
# loop done: 100%
# ##################
# ##################
# Run 4269 is empty!
# ##################
# ##################
#
#
# Saving run 4270.
# Fixed probe run.
# Cannot load ids, no data present
#
# loop done: 100%
# ##################
# ##################
# Run 4270 is empty!
# ##################
# ##################
#
#
# Saving run 4271.
# Trolley run.
# Reading event 1460/1463 99.79%
# loop done: 100%
# Reading event 430/439 97.95%
# loop done: 100%
# Interpolating trolley position.
# Interpolating trolley frequencies.
# Interpolating fixed probe frequencies.
# ...
